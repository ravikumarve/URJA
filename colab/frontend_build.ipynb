# %% [markdown]
# # URJA Frontend — Build Farm (No Fan)
# Offload `npm ci && npm run build` from Latitude. 27s → 8s.

# %%
# !test -d URJA || git clone https://github.com/ravikumarve/URJA.git --depth 1
# %cd URJA/frontend
# !node -v; npm -v
# !npm ci --progress=false 2>&1 | tail -5
print("deps done")
# Out:
# Cloning into 'URJA'...
# remote: Enumerating objects: 182, done.
# remote: Counting objects: 100% (182/182), done.
# remote: Compressing objects: 100% (164/164), done.
# remote: Total 182 (delta 12), reused 136 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (182/182), 725.85 KiB | 12.30 MiB/s, done.
# Resolving deltas: 100% (12/12), done.
# /content/URJA/frontend
# v20.19.0
# 10.8.2
#
# To address all issues, run:
#   npm audit fix
#
# Run `npm audit` for details.
# deps done

# %%
# !npm run build 2>&1 | tail -20
print("✅ build done")
# Out:
#   Generating static pages using 1 worker (0/9) ...
#   Generating static pages using 1 worker (2/9)
#   Generating static pages using 1 worker (4/9)
#   Generating static pages using 1 worker (6/9)
# ✓ Generating static pages using 1 worker (9/9) in 463ms
#   Finalizing page optimization ...
#
# Route (app)
# ┌ ○ /
# ├ ○ /_not-found
# ├ ○ /assets
# ├ ○ /carbon
# ├ ○ /health
# ├ ○ /login
# ├ ○ /settings
# └ ○ /yield
#
#
# ○  (Static)  prerendered as static content
#
# ✅ build done

# %%
# !npx tsc --noEmit 2>&1 | tail -10
print("typecheck done")
# Out:
# typecheck done
